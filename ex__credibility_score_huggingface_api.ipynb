# %%
import pandas as pd
import requests
from io import StringIO

def download_and_combine_csv(urls: list) -> pd.DataFrame:
    """
    Download CSV files from provided URLs and combine them row-wise.
    It will combine files if they have the expected column names or just the correct number of columns.
    Handles different encodings to avoid common decoding errors. Converts certain columns to integer form.

    Args:
    urls (list): List of strings containing the URLs of the CSV files.

    Returns:
    pd.DataFrame: A DataFrame containing the combined data from all matching CSV files.
    """
    expected_columns = {'user_prompt', 'url_to_check', 'func_rating', 'custom_rating'}
    combined_df = pd.DataFrame()

    for url in urls:
        try:
            # Modify the GitHub URL to point to the raw version of the file
            raw_url = url.replace('github.com', 'raw.githubusercontent.com').replace('/blob', '')

            response = requests.get(raw_url)
            if response.status_code == 200:
                try:
                    # Attempt to read with utf-8 encoding
                    content = response.content.decode('utf-8')
                except UnicodeDecodeError:
                    # Attempt to read with latin1 encoding
                    content = response.content.decode('latin1')

                # Read the CSV file into a DataFrame
                df = pd.read_csv(StringIO(content))

                # Check if the columns match the expected columns or if there are at least 4 columns
                if set(df.columns) == expected_columns:
                    combined_df = pd.concat([combined_df, df], ignore_index=True)
                elif len(df.columns) >= 4:
                    # Assume the first 4 columns are the required ones and ignore the original column names
                    df = df.iloc[:, :4]
                    df.columns = ['user_prompt', 'url_to_check', 'func_rating', 'custom_rating']
                    combined_df = pd.concat([combined_df, df], ignore_index=True)
                else:
                    print(f"Skipping file with insufficient columns: {url}")
            else:
                print(f"Failed to download from {url}")
        except Exception as e:
            print(f"Error processing {url}: {str(e)}")

    # Ensure func_rating and custom_rating are integers
    if not combined_df.empty:
        combined_df['func_rating'] = combined_df['func_rating'].round().astype(int)
        combined_df['custom_rating'] = combined_df['custom_rating'].round().astype(int)

    return combined_df

# %%
# Example usage:
urls = [
    "https://github.com/vrutika-prajapati/Credibility-Score-for-Articles/blob/main/projects/deliverable%202/Url_validation.csv",
    "https://github.com/Saikumar08-sk/URL-Validation/blob/main/Deliverable.csv",
    "https://github.com/aditya19111/Project-1-Credibility-Score-for-Articles-Sources-References/blob/main/Deliverable_2/Deliverables_rating_comparison%20-%20Sheet1.csv",
    "https://github.com/SAIKUMAR500/algorithums-for-data-science/blob/main/deliverable2/dataset(Sheet1).csv",
    "https://github.com/drashti-sanghani/Credibility_score_articles/blob/main/Project/Deliverable2/user_ratings.csv",
    "https://github.com/anchalrai101/CREDIBILITY-SCORE/blob/main/urltesting_scores.csv",
    "https://github.com/AliSInamdar/CS676-Ali-Inamdar/blob/Project_1_Credibilty_Score/Deliverable_2/Deliverable_2.csv",
    "https://github.com/bhavnaa22/Algorithms-For-Data-Science/blob/main/Deliverable%202/Deliverable2.csv",
    "https://github.com/bhatthardik4/AlgorithmDS/blob/main/Deliverable_2/HardikBhattD2.csv",
    "https://github.com/Rakeshkanche/Algorithms-for-Data-Science/blob/main/queries_urls_ratings.csv",
    "https://github.com/kristinakim-code/Credibility-Check/blob/main/deliverable2.csv",
    "https://github.com/bhavnaa22/Algorithms-For-Data-Science/blob/main/Deliverable%202/Deliverable2.csv",
    "https://github.com/kamaldomandula/Algorithms-of-data-science-Project/blob/main/Project/project1/Deliverable2/deliverable.csv",
    "https://github.com/ChinmayShetye26/Algo-for-DS-delivery2/blob/main/Sample.csv",
    "https://github.com/krishnam229/Project1/blob/main/deliverable2/sample.csv",
    "https://github.com/drona23/Deliverable2/blob/main/output.csv",
    "https://github.com/JoshuaGottlieb/Chatbot-Credibility-Scorer/blob/main/src/deliverable-02/testing/sample.csv"
]

# %%
result_df = download_and_combine_csv(urls)
print(result_df)
# Out:
#                                            user_prompt  \
# 0    I have just been on an international flight, c...
# 1          What are the benefits of a vegetarian diet?
# 2          What are the benefits of a vegetarian diet?
# 3          What are the benefits of a vegetarian diet?
# 4    How to improve mental health during stressful ...
# ..                                                 ...
# 297  How does altitude training affect endurance in...
# 298  What are the safest travel destinations for so...
# 299  How can travelers find sustainable and eco-fri...
# 300  What cultural experiences should not be missed...
# 301  How do budget travel options compare to luxury...
#
#                                           url_to_check  func_rating  \
# 0    https://www.mayoclinic.org/healthy-lifestyle/i...            2
# 1    https://www.nhs.uk/live-well/eat-well/how-to-e...            2
# 2    https://www.nhs.uk/live-well/eat-well/how-to-e...            2
# 3    https://pubmed.ncbi.nlm.nih.gov/37226630/#:~:t...            2
# 4    https://www.who.int/news-room/questions-and-an...            3
# ..                                                 ...          ...
# 297  https://sports.stackexchange.com/questions/498...            3
# 298  https://www.exploreworldwide.com/blog/top-solo...            3
# 299  https://www.peekpro.com/blog/sustainable-touri...            3
# 300  https://www.insidejapantours.com/blog/2015/08/...            2
# 301  https://traveltillyoudrop.com/budget-travel-vs...            3
#
#      custom_rating
# 0                3
# 1                4
# 2                2
# 3                3
# 4                3
# ..             ...
# 297              3
# 298              2
# 299              3
# 300              4
# 301              4
#
# [302 rows x 4 columns]

# %%
result_df
# Out:
#                                            user_prompt  \
# 0    I have just been on an international flight, c...
# 1          What are the benefits of a vegetarian diet?
# 2          What are the benefits of a vegetarian diet?
# 3          What are the benefits of a vegetarian diet?
# 4    How to improve mental health during stressful ...
# ..                                                 ...
# 297  How does altitude training affect endurance in...
# 298  What are the safest travel destinations for so...
# 299  How can travelers find sustainable and eco-fri...
# 300  What cultural experiences should not be missed...
# 301  How do budget travel options compare to luxury...
#
#                                           url_to_check  func_rating  \
# 0    https://www.mayoclinic.org/healthy-lifestyle/i...            2
# 1    https://www.nhs.uk/live-well/eat-well/how-to-e...            2
# 2    https://www.nhs.uk/live-well/eat-well/how-to-e...            2
# 3    https://pubmed.ncbi.nlm.nih.gov/37226630/#:~:t...            2
# 4    https://www.who.int/news-room/questions-and-an...            3
# ..                                                 ...          ...
# 297  https://sports.stackexchange.com/questions/498...            3
# 298  https://www.exploreworldwide.com/blog/top-solo...            3
# 299  https://www.peekpro.com/blog/sustainable-touri...            3
# 300  https://www.insidejapantours.com/blog/2015/08/...            2
# 301  https://traveltillyoudrop.com/budget-travel-vs...            3
#
#      custom_rating
# 0                3
# 1                4
# 2                2
# 3                3
# 4                3
# ..             ...
# 297              3
# 298              2
# 299              3
# 300              4
# 301              4
#
# [302 rows x 4 columns]

# %%
from google.colab import files

result_df.to_csv('result.csv', index=False)
files.download('result.csv')

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, Dense, Concatenate, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
import pandas as pd

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Dense, Concatenate, Flatten

# Define function to create the neural network model
def create_nn_model(vocab_size: int, embedding_dim: int, max_length: int, num_of_dense: int, output_dim: int) -> Model:
    """
    Creates a neural network model that processes user prompts using an embedding layer,
    concatenates it with function ratings, and passes through dense layers.

    Args:
        vocab_size (int): Size of the vocabulary for embedding.
        embedding_dim (int): Dimensionality of the embedding layer.
        max_length (int): Maximum length of input sequences.
        num_of_dense (int): Number of dense layers before concatenation.

    Returns:
        Model: A compiled TensorFlow model.
    """
    # Text input (user prompt)
    text_input = Input(shape=(max_length,), name="text_input")
    embedding = Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_length)(text_input)
    flatten = Flatten()(embedding)

    # Dense layers for text input
    num_neurons = 2**12  # Start with 4096 neurons
    x = flatten
    for _ in range(num_of_dense):
        num_neurons = max(1, int(num_neurons / 2))  # Ensure integer neurons, minimum of 1
        x = Dense(num_neurons, activation='relu')(x)

    # Numeric input (func_rating)
    func_rating_input = Input(shape=(1,), name="func_rating_input")
    y = Dense(32, activation='relu')(func_rating_input)

    # Concatenate both paths
    concatenated = Concatenate()([x, y])
    # output = Dense(1, activation='linear', name="output")(concatenated)
    output = Dense(output_dim, activation='softmax', name="output")(concatenated)

    # Define and compile the model
    model = Model(inputs=[text_input, func_rating_input], outputs=output)

    # Set up learning rate scheduler
    # code here:

    # Compile
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
# Generate a larger sample dataset with 20 rows
data = {
    "user_prompt": [
        "I have just been on an international flight",
        "How can I improve my sleep quality?",
        "What are the symptoms of vitamin D deficiency?",
        "Best exercises for lower back pain relief",
        "Healthy meal ideas for weight loss",
        "How to reduce stress and anxiety naturally?",
        "What are the benefits of intermittent fasting?",
        "Tips for maintaining healthy skin",
        "How much water should I drink daily?",
        "Best ways to boost immune system",
        "Exercises to improve posture",
        "How to manage time effectively?",
        "Signs and symptoms of dehydration",
        "What foods help lower cholesterol?",
        "How to stay productive while working remotely?",
        "What are the dangers of processed foods?",
        "How to get better sleep without medication?",
        "Ways to increase energy levels naturally",
        "How does meditation help mental health?",
        "Best strategies to quit smoking"
    ],
    "func_rating": [3, 4, 2, 5, 3, 4, 5, 3, 4, 5, 3, 4, 2, 5, 3, 4, 5, 3, 4, 5],
    "custom_rating": [4, 5, 3, 4, 4, 5, 5, 4, 4, 5, 3, 5, 3, 4, 4, 3, 5, 4, 4, 5]
}

# Convert to DataFrame and display
df = pd.DataFrame(data)

# %%
df["custom_rating"].unique()
# Out:
# array([4, 5, 3])

# %%
df.shape
# Out:
# (20, 3)

# %%
# Tokenize and prepare data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df["user_prompt"])
vocab_size = len(tokenizer.word_index) + 1
max_length = max([len(x.split()) for x in df["user_prompt"]])
embedding_dim = 16

# Convert text data into sequences
X_text = tokenizer.texts_to_sequences(df["user_prompt"])
X_text = pad_sequences(X_text, maxlen=max_length, padding='post')
print(X_text.shape)

# Numeric input
X_func_rating = np.array(df["func_rating"]).reshape(-1, 1)
print(X_func_rating.shape)

# Target variable
y = np.array(df["custom_rating"]).reshape(-1, 1)
print(y.shape)
# Out:
# (20, 8)
# (20, 1)
# (20, 1)

# %%
df["custom_rating"].unique()
# Out:
# array([4, 5, 3])

# %%
from keras.utils import to_categorical

# Assuming y is your array of class labels shaped as (20, 1)
# Convert labels to one-hot encoding
y_one_hot = to_categorical(y)

# Check the new shape of y_one_hot
print(y_one_hot.shape)
# Out:
# (20, 6)

# %%
num_of_dense_layers = 3  # Example: 2 dense layers before concatenation
output_dim = y_one_hot.shape[1] # Get the output dimension from the one-hot encoded target variable
model = create_nn_model(vocab_size, embedding_dim, max_length, num_of_dense_layers, output_dim)

# %%
# %%time

# Train the model
model.fit(
    {"text_input": X_text, "func_rating_input": X_func_rating},
    y_one_hot,
    epochs=2000,
    batch_size=32,
    validation_split=0.1,
    verbose=2
)
# Out:
# Epoch 1/2000
# 4/4 - 1s - 234ms/step - accuracy: 0.9474 - loss: 0.3572 - val_accuracy: 0.0000e+00 - val_loss: 20.0360
# Epoch 2/2000
# 4/4 - 0s - 109ms/step - accuracy: 0.6842 - loss: 1.3400 - val_accuracy: 1.0000 - val_loss: 0.0757
# Epoch 3/2000
# 4/4 - 0s - 48ms/step - accuracy: 0.8947 - loss: 0.1473 - val_accuracy: 1.0000 - val_loss: 6.5472e-04
# Epoch 4/2000
# 4/4 - 0s - 71ms/step - accuracy: 0.9474 - loss: 0.0575 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 5/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 2.8683e-05 - val_accuracy: 1.0000 - val_loss: 0.0787
# Epoch 6/2000
# 4/4 - 0s - 81ms/step - accuracy: 1.0000 - loss: 3.8187e-05 - val_accuracy: 1.0000 - val_loss: 0.3434
# Epoch 7/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 8.3304e-05 - val_accuracy: 1.0000 - val_loss: 0.6936
# Epoch 8/2000
# 4/4 - 0s - 42ms/step - accuracy: 1.0000 - loss: 1.0348e-04 - val_accuracy: 0.0000e+00 - val_loss: 0.8475
# Epoch 9/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 8.3790e-05 - val_accuracy: 0.0000e+00 - val_loss: 0.8828
# Epoch 10/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 3.8482e-05 - val_accuracy: 0.0000e+00 - val_loss: 0.8806
# Epoch 11/2000
# 4/4 - 0s - 40ms/step - accuracy: 1.0000 - loss: 2.1147e-05 - val_accuracy: 0.0000e+00 - val_loss: 0.8537
# Epoch 12/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 9.3228e-06 - val_accuracy: 0.0000e+00 - val_loss: 0.8190
# Epoch 13/2000
# 4/4 - 0s - 81ms/step - accuracy: 1.0000 - loss: 4.4608e-06 - val_accuracy: 0.0000e+00 - val_loss: 0.7852
# Epoch 14/2000
# 4/4 - 0s - 91ms/step - accuracy: 1.0000 - loss: 3.0617e-06 - val_accuracy: 0.0000e+00 - val_loss: 0.7545
# Epoch 15/2000
# 4/4 - 0s - 62ms/step - accuracy: 1.0000 - loss: 1.5811e-06 - val_accuracy: 0.0000e+00 - val_loss: 0.7329
# Epoch 16/2000
# 4/4 - 0s - 90ms/step - accuracy: 1.0000 - loss: 1.3929e-06 - val_accuracy: 0.0000e+00 - val_loss: 0.7141
# Epoch 17/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 9.9132e-07 - val_accuracy: 1.0000 - val_loss: 0.7046
# Epoch 18/2000
# 4/4 - 0s - 66ms/step - accuracy: 1.0000 - loss: 8.2819e-07 - val_accuracy: 1.0000 - val_loss: 0.6975
# Epoch 19/2000
# 4/4 - 0s - 50ms/step - accuracy: 1.0000 - loss: 7.6545e-07 - val_accuracy: 1.0000 - val_loss: 0.6942
# Epoch 20/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 6.5251e-07 - val_accuracy: 1.0000 - val_loss: 0.6929
# Epoch 21/2000
# 4/4 - 0s - 49ms/step - accuracy: 1.0000 - loss: 5.7095e-07 - val_accuracy: 1.0000 - val_loss: 0.6927
# Epoch 22/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 5.1448e-07 - val_accuracy: 1.0000 - val_loss: 0.6929
# Epoch 23/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 4.7056e-07 - val_accuracy: 1.0000 - val_loss: 0.6935
# Epoch 24/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 4.2664e-07 - val_accuracy: 1.0000 - val_loss: 0.6951
# Epoch 25/2000
# 4/4 - 0s - 50ms/step - accuracy: 1.0000 - loss: 4.0782e-07 - val_accuracy: 1.0000 - val_loss: 0.6967
# Epoch 26/2000
# 4/4 - 0s - 69ms/step - accuracy: 1.0000 - loss: 3.7018e-07 - val_accuracy: 1.0000 - val_loss: 0.6980
# Epoch 27/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 3.5135e-07 - val_accuracy: 1.0000 - val_loss: 0.6997
# Epoch 28/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 3.3880e-07 - val_accuracy: 1.0000 - val_loss: 0.6996
# Epoch 29/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 3.1371e-07 - val_accuracy: 1.0000 - val_loss: 0.6994
# Epoch 30/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 2.8861e-07 - val_accuracy: 1.0000 - val_loss: 0.6993
# Epoch 31/2000
# 4/4 - 0s - 70ms/step - accuracy: 1.0000 - loss: 2.7606e-07 - val_accuracy: 1.0000 - val_loss: 0.6986
# Epoch 32/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 2.5724e-07 - val_accuracy: 1.0000 - val_loss: 0.6983
# Epoch 33/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 2.5724e-07 - val_accuracy: 1.0000 - val_loss: 0.6987
# Epoch 34/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 2.3214e-07 - val_accuracy: 1.0000 - val_loss: 0.6997
# Epoch 35/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 2.1960e-07 - val_accuracy: 1.0000 - val_loss: 0.6989
# Epoch 36/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 2.1332e-07 - val_accuracy: 1.0000 - val_loss: 0.6980
# Epoch 37/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 2.0077e-07 - val_accuracy: 1.0000 - val_loss: 0.6970
# Epoch 38/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 1.8823e-07 - val_accuracy: 1.0000 - val_loss: 0.6967
# Epoch 39/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 1.8823e-07 - val_accuracy: 1.0000 - val_loss: 0.6964
# Epoch 40/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 1.8195e-07 - val_accuracy: 1.0000 - val_loss: 0.6956
# Epoch 41/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 1.7568e-07 - val_accuracy: 1.0000 - val_loss: 0.6951
# Epoch 42/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 1.6940e-07 - val_accuracy: 1.0000 - val_loss: 0.6944
# Epoch 43/2000
# 4/4 - 0s - 40ms/step - accuracy: 1.0000 - loss: 1.5685e-07 - val_accuracy: 1.0000 - val_loss: 0.6941
# Epoch 44/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 1.5058e-07 - val_accuracy: 1.0000 - val_loss: 0.6934
# Epoch 45/2000
# 4/4 - 0s - 49ms/step - accuracy: 1.0000 - loss: 1.5058e-07 - val_accuracy: 1.0000 - val_loss: 0.6928
# Epoch 46/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 1.5058e-07 - val_accuracy: 1.0000 - val_loss: 0.6924
# Epoch 47/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 1.3803e-07 - val_accuracy: 1.0000 - val_loss: 0.6921
# Epoch 48/2000
# 4/4 - 0s - 68ms/step - accuracy: 1.0000 - loss: 1.2548e-07 - val_accuracy: 1.0000 - val_loss: 0.6910
# Epoch 49/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 1.1921e-07 - val_accuracy: 1.0000 - val_loss: 0.6902
# Epoch 50/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 1.1294e-07 - val_accuracy: 1.0000 - val_loss: 0.6899
# Epoch 51/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 1.1294e-07 - val_accuracy: 1.0000 - val_loss: 0.6895
# Epoch 52/2000
# 4/4 - 0s - 81ms/step - accuracy: 1.0000 - loss: 1.1294e-07 - val_accuracy: 1.0000 - val_loss: 0.6882
# Epoch 53/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 1.0666e-07 - val_accuracy: 1.0000 - val_loss: 0.6875
# Epoch 54/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 1.0666e-07 - val_accuracy: 1.0000 - val_loss: 0.6876
# Epoch 55/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 1.0666e-07 - val_accuracy: 1.0000 - val_loss: 0.6865
# Epoch 56/2000
# 4/4 - 0s - 68ms/step - accuracy: 1.0000 - loss: 1.0039e-07 - val_accuracy: 1.0000 - val_loss: 0.6856
# Epoch 57/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 9.4113e-08 - val_accuracy: 1.0000 - val_loss: 0.6857
# Epoch 58/2000
# 4/4 - 0s - 40ms/step - accuracy: 1.0000 - loss: 8.7838e-08 - val_accuracy: 1.0000 - val_loss: 0.6851
# Epoch 59/2000
# 4/4 - 0s - 79ms/step - accuracy: 1.0000 - loss: 8.7838e-08 - val_accuracy: 1.0000 - val_loss: 0.6840
# Epoch 60/2000
# 4/4 - 0s - 55ms/step - accuracy: 1.0000 - loss: 8.1564e-08 - val_accuracy: 1.0000 - val_loss: 0.6832
# Epoch 61/2000
# 4/4 - 0s - 56ms/step - accuracy: 1.0000 - loss: 8.1564e-08 - val_accuracy: 1.0000 - val_loss: 0.6828
# Epoch 62/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 8.1564e-08 - val_accuracy: 1.0000 - val_loss: 0.6823
# Epoch 63/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 7.5290e-08 - val_accuracy: 1.0000 - val_loss: 0.6823
# Epoch 64/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 7.5290e-08 - val_accuracy: 1.0000 - val_loss: 0.6819
# Epoch 65/2000
# 4/4 - 0s - 49ms/step - accuracy: 1.0000 - loss: 7.5290e-08 - val_accuracy: 1.0000 - val_loss: 0.6811
# Epoch 66/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 7.5290e-08 - val_accuracy: 1.0000 - val_loss: 0.6803
# Epoch 67/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 7.5290e-08 - val_accuracy: 1.0000 - val_loss: 0.6803
# Epoch 68/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 7.5290e-08 - val_accuracy: 1.0000 - val_loss: 0.6795
# Epoch 69/2000
# 4/4 - 0s - 70ms/step - accuracy: 1.0000 - loss: 6.9016e-08 - val_accuracy: 1.0000 - val_loss: 0.6793
# Epoch 70/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 6.9016e-08 - val_accuracy: 1.0000 - val_loss: 0.6790
# Epoch 71/2000
# 4/4 - 0s - 81ms/step - accuracy: 1.0000 - loss: 6.9016e-08 - val_accuracy: 1.0000 - val_loss: 0.6786
# Epoch 72/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 6.9016e-08 - val_accuracy: 1.0000 - val_loss: 0.6780
# Epoch 73/2000
# 4/4 - 0s - 49ms/step - accuracy: 1.0000 - loss: 6.9016e-08 - val_accuracy: 1.0000 - val_loss: 0.6777
# Epoch 74/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 6.9016e-08 - val_accuracy: 1.0000 - val_loss: 0.6774
# Epoch 75/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 6.2742e-08 - val_accuracy: 1.0000 - val_loss: 0.6772
# Epoch 76/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 5.6468e-08 - val_accuracy: 1.0000 - val_loss: 0.6777
# Epoch 77/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 5.6468e-08 - val_accuracy: 1.0000 - val_loss: 0.6772
# Epoch 78/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 5.0193e-08 - val_accuracy: 1.0000 - val_loss: 0.6766
# Epoch 79/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 5.0193e-08 - val_accuracy: 1.0000 - val_loss: 0.6764
# Epoch 80/2000
# 4/4 - 0s - 41ms/step - accuracy: 1.0000 - loss: 5.0193e-08 - val_accuracy: 1.0000 - val_loss: 0.6760
# Epoch 81/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 5.0193e-08 - val_accuracy: 1.0000 - val_loss: 0.6755
# Epoch 82/2000
# 4/4 - 0s - 49ms/step - accuracy: 1.0000 - loss: 5.0193e-08 - val_accuracy: 1.0000 - val_loss: 0.6753
# Epoch 83/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 5.0193e-08 - val_accuracy: 1.0000 - val_loss: 0.6751
# Epoch 84/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 4.3919e-08 - val_accuracy: 1.0000 - val_loss: 0.6750
# Epoch 85/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 4.3919e-08 - val_accuracy: 1.0000 - val_loss: 0.6751
# Epoch 86/2000
# 4/4 - 0s - 70ms/step - accuracy: 1.0000 - loss: 4.3919e-08 - val_accuracy: 1.0000 - val_loss: 0.6750
# Epoch 87/2000
# 4/4 - 0s - 42ms/step - accuracy: 1.0000 - loss: 4.3919e-08 - val_accuracy: 1.0000 - val_loss: 0.6745
# Epoch 88/2000
# 4/4 - 0s - 83ms/step - accuracy: 1.0000 - loss: 4.3919e-08 - val_accuracy: 1.0000 - val_loss: 0.6743
# Epoch 89/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 4.3919e-08 - val_accuracy: 1.0000 - val_loss: 0.6740
# Epoch 90/2000
# 4/4 - 0s - 50ms/step - accuracy: 1.0000 - loss: 4.3919e-08 - val_accuracy: 1.0000 - val_loss: 0.6737
# Epoch 91/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 4.3919e-08 - val_accuracy: 1.0000 - val_loss: 0.6733
# Epoch 92/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 4.3919e-08 - val_accuracy: 1.0000 - val_loss: 0.6732
# Epoch 93/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 4.3919e-08 - val_accuracy: 1.0000 - val_loss: 0.6732
# Epoch 94/2000
# 4/4 - 0s - 40ms/step - accuracy: 1.0000 - loss: 4.3919e-08 - val_accuracy: 1.0000 - val_loss: 0.6729
# Epoch 95/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 3.7645e-08 - val_accuracy: 1.0000 - val_loss: 0.6725
# Epoch 96/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 3.7645e-08 - val_accuracy: 1.0000 - val_loss: 0.6720
# Epoch 97/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 3.7645e-08 - val_accuracy: 1.0000 - val_loss: 0.6718
# Epoch 98/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 3.7645e-08 - val_accuracy: 1.0000 - val_loss: 0.6713
# Epoch 99/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6709
# Epoch 100/2000
# 4/4 - 0s - 79ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6706
# Epoch 101/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6702
# Epoch 102/2000
# 4/4 - 0s - 49ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6700
# Epoch 103/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6699
# Epoch 104/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6695
# Epoch 105/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6692
# Epoch 106/2000
# 4/4 - 0s - 102ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6687
# Epoch 107/2000
# 4/4 - 0s - 69ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6686
# Epoch 108/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6682
# Epoch 109/2000
# 4/4 - 0s - 81ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6678
# Epoch 110/2000
# 4/4 - 0s - 39ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6672
# Epoch 111/2000
# 4/4 - 0s - 81ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6669
# Epoch 112/2000
# 4/4 - 0s - 41ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6665
# Epoch 113/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6665
# Epoch 114/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6661
# Epoch 115/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6658
# Epoch 116/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6654
# Epoch 117/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6650
# Epoch 118/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6646
# Epoch 119/2000
# 4/4 - 0s - 81ms/step - accuracy: 1.0000 - loss: 3.1371e-08 - val_accuracy: 1.0000 - val_loss: 0.6644
# Epoch 120/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 2.5097e-08 - val_accuracy: 1.0000 - val_loss: 0.6640
# Epoch 121/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 2.5097e-08 - val_accuracy: 1.0000 - val_loss: 0.6639
# Epoch 122/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 2.5097e-08 - val_accuracy: 1.0000 - val_loss: 0.6637
# Epoch 123/2000
# 4/4 - 0s - 41ms/step - accuracy: 1.0000 - loss: 2.5097e-08 - val_accuracy: 1.0000 - val_loss: 0.6635
# Epoch 124/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 2.5097e-08 - val_accuracy: 1.0000 - val_loss: 0.6632
# Epoch 125/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 2.5097e-08 - val_accuracy: 1.0000 - val_loss: 0.6630
# Epoch 126/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 2.5097e-08 - val_accuracy: 1.0000 - val_loss: 0.6628
# Epoch 127/2000
# 4/4 - 0s - 42ms/step - accuracy: 1.0000 - loss: 2.5097e-08 - val_accuracy: 1.0000 - val_loss: 0.6624
# Epoch 128/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 2.5097e-08 - val_accuracy: 1.0000 - val_loss: 0.6624
# Epoch 129/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 2.5097e-08 - val_accuracy: 1.0000 - val_loss: 0.6621
# Epoch 130/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 2.5097e-08 - val_accuracy: 1.0000 - val_loss: 0.6617
# Epoch 131/2000
# 4/4 - 0s - 41ms/step - accuracy: 1.0000 - loss: 2.5097e-08 - val_accuracy: 1.0000 - val_loss: 0.6615
# Epoch 132/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 2.5097e-08 - val_accuracy: 1.0000 - val_loss: 0.6615
# Epoch 133/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 2.5097e-08 - val_accuracy: 1.0000 - val_loss: 0.6611
# Epoch 134/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 2.5097e-08 - val_accuracy: 1.0000 - val_loss: 0.6608
# Epoch 135/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 2.5097e-08 - val_accuracy: 1.0000 - val_loss: 0.6605
# Epoch 136/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 2.5097e-08 - val_accuracy: 1.0000 - val_loss: 0.6604
# Epoch 137/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6605
# Epoch 138/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6605
# Epoch 139/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6603
# Epoch 140/2000
# 4/4 - 0s - 42ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6600
# Epoch 141/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6599
# Epoch 142/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6597
# Epoch 143/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6596
# Epoch 144/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6597
# Epoch 145/2000
# 4/4 - 0s - 79ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6595
# Epoch 146/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6594
# Epoch 147/2000
# 4/4 - 0s - 70ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6593
# Epoch 148/2000
# 4/4 - 0s - 42ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6592
# Epoch 149/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6591
# Epoch 150/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6591
# Epoch 151/2000
# 4/4 - 0s - 95ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6589
# Epoch 152/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6589
# Epoch 153/2000
# 4/4 - 0s - 81ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6587
# Epoch 154/2000
# 4/4 - 0s - 62ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6584
# Epoch 155/2000
# 4/4 - 0s - 68ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6584
# Epoch 156/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 1.8823e-08 - val_accuracy: 1.0000 - val_loss: 0.6583
# Epoch 157/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 1.2548e-08 - val_accuracy: 1.0000 - val_loss: 0.6581
# Epoch 158/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 1.2548e-08 - val_accuracy: 1.0000 - val_loss: 0.6579
# Epoch 159/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 1.2548e-08 - val_accuracy: 1.0000 - val_loss: 0.6575
# Epoch 160/2000
# 4/4 - 0s - 82ms/step - accuracy: 1.0000 - loss: 1.2548e-08 - val_accuracy: 1.0000 - val_loss: 0.6572
# Epoch 161/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 1.2548e-08 - val_accuracy: 1.0000 - val_loss: 0.6568
# Epoch 162/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 1.2548e-08 - val_accuracy: 1.0000 - val_loss: 0.6561
# Epoch 163/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6557
# Epoch 164/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6553
# Epoch 165/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6549
# Epoch 166/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6545
# Epoch 167/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6542
# Epoch 168/2000
# 4/4 - 0s - 50ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6539
# Epoch 169/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6536
# Epoch 170/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6534
# Epoch 171/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6531
# Epoch 172/2000
# 4/4 - 0s - 80ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6530
# Epoch 173/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6529
# Epoch 174/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6526
# Epoch 175/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6524
# Epoch 176/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6522
# Epoch 177/2000
# 4/4 - 0s - 70ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6519
# Epoch 178/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6515
# Epoch 179/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6513
# Epoch 180/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6510
# Epoch 181/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6508
# Epoch 182/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6506
# Epoch 183/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6504
# Epoch 184/2000
# 4/4 - 0s - 40ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6501
# Epoch 185/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6497
# Epoch 186/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6494
# Epoch 187/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6491
# Epoch 188/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6489
# Epoch 189/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6487
# Epoch 190/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6485
# Epoch 191/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6482
# Epoch 192/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6480
# Epoch 193/2000
# 4/4 - 0s - 42ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6477
# Epoch 194/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6473
# Epoch 195/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6471
# Epoch 196/2000
# 4/4 - 0s - 94ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6469
# Epoch 197/2000
# 4/4 - 0s - 85ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6467
# Epoch 198/2000
# 4/4 - 0s - 63ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6464
# Epoch 199/2000
# 4/4 - 0s - 81ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6461
# Epoch 200/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6459
# Epoch 201/2000
# 4/4 - 0s - 63ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6457
# Epoch 202/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6456
# Epoch 203/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6454
# Epoch 204/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6452
# Epoch 205/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6450
# Epoch 206/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6447
# Epoch 207/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6446
# Epoch 208/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6443
# Epoch 209/2000
# 4/4 - 0s - 81ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6441
# Epoch 210/2000
# 4/4 - 0s - 41ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6437
# Epoch 211/2000
# 4/4 - 0s - 40ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6434
# Epoch 212/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6431
# Epoch 213/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6429
# Epoch 214/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6427
# Epoch 215/2000
# 4/4 - 0s - 68ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6425
# Epoch 216/2000
# 4/4 - 0s - 80ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6422
# Epoch 217/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6419
# Epoch 218/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6417
# Epoch 219/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6414
# Epoch 220/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6413
# Epoch 221/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6411
# Epoch 222/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6409
# Epoch 223/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6407
# Epoch 224/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6404
# Epoch 225/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6400
# Epoch 226/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6397
# Epoch 227/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6395
# Epoch 228/2000
# 4/4 - 0s - 49ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6393
# Epoch 229/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6391
# Epoch 230/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6389
# Epoch 231/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6386
# Epoch 232/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6384
# Epoch 233/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6382
# Epoch 234/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6379
# Epoch 235/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6377
# Epoch 236/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6375
# Epoch 237/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6373
# Epoch 238/2000
# 4/4 - 0s - 49ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6371
# Epoch 239/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6369
# Epoch 240/2000
# 4/4 - 0s - 52ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6368
# Epoch 241/2000
# 4/4 - 0s - 65ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6365
# Epoch 242/2000
# 4/4 - 0s - 86ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6363
# Epoch 243/2000
# 4/4 - 1s - 148ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6360
# Epoch 244/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6358
# Epoch 245/2000
# 4/4 - 0s - 50ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6356
# Epoch 246/2000
# 4/4 - 0s - 69ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6355
# Epoch 247/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6353
# Epoch 248/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6351
# Epoch 249/2000
# 4/4 - 0s - 70ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6348
# Epoch 250/2000
# 4/4 - 0s - 81ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6347
# Epoch 251/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6345
# Epoch 252/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6343
# Epoch 253/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6340
# Epoch 254/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6338
# Epoch 255/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6336
# Epoch 256/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6334
# Epoch 257/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6332
# Epoch 258/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6331
# Epoch 259/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6329
# Epoch 260/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6326
# Epoch 261/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6323
# Epoch 262/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6320
# Epoch 263/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6318
# Epoch 264/2000
# 4/4 - 0s - 49ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6316
# Epoch 265/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6314
# Epoch 266/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6312
# Epoch 267/2000
# 4/4 - 0s - 42ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6310
# Epoch 268/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6308
# Epoch 269/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6305
# Epoch 270/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6303
# Epoch 271/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6301
# Epoch 272/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6300
# Epoch 273/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6297
# Epoch 274/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6296
# Epoch 275/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6295
# Epoch 276/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6291
# Epoch 277/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6290
# Epoch 278/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6288
# Epoch 279/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6285
# Epoch 280/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6282
# Epoch 281/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6279
# Epoch 282/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6278
# Epoch 283/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6276
# Epoch 284/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6273
# Epoch 285/2000
# 4/4 - 0s - 57ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 286/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6270
# Epoch 287/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6269
# Epoch 288/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6267
# Epoch 289/2000
# 4/4 - 1s - 131ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6264
# Epoch 290/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6260
# Epoch 291/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6257
# Epoch 292/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6255
# Epoch 293/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6254
# Epoch 294/2000
# 4/4 - 0s - 42ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6253
# Epoch 295/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6250
# Epoch 296/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6248
# Epoch 297/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6246
# Epoch 298/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6244
# Epoch 299/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6242
# Epoch 300/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6239
# Epoch 301/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6238
# Epoch 302/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6235
# Epoch 303/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6233
# Epoch 304/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6231
# Epoch 305/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6228
# Epoch 306/2000
# 4/4 - 0s - 69ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6226
# Epoch 307/2000
# 4/4 - 0s - 41ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6225
# Epoch 308/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6223
# Epoch 309/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6220
# Epoch 310/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6218
# Epoch 311/2000
# 4/4 - 0s - 42ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6216
# Epoch 312/2000
# 4/4 - 0s - 83ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6214
# Epoch 313/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6211
# Epoch 314/2000
# 4/4 - 0s - 70ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6209
# Epoch 315/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6207
# Epoch 316/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6204
# Epoch 317/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6203
# Epoch 318/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6200
# Epoch 319/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6199
# Epoch 320/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 6.2742e-09 - val_accuracy: 1.0000 - val_loss: 0.6197
# Epoch 321/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6195
# Epoch 322/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6195
# Epoch 323/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6194
# Epoch 324/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6194
# Epoch 325/2000
# 4/4 - 0s - 54ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6194
# Epoch 326/2000
# 4/4 - 0s - 41ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6194
# Epoch 327/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6195
# Epoch 328/2000
# 4/4 - 0s - 40ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6195
# Epoch 329/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6196
# Epoch 330/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6195
# Epoch 331/2000
# 4/4 - 0s - 89ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6195
# Epoch 332/2000
# 4/4 - 0s - 56ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6196
# Epoch 333/2000
# 4/4 - 0s - 59ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6197
# Epoch 334/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6197
# Epoch 335/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6197
# Epoch 336/2000
# 4/4 - 0s - 60ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6198
# Epoch 337/2000
# 4/4 - 0s - 70ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6198
# Epoch 338/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6198
# Epoch 339/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6199
# Epoch 340/2000
# 4/4 - 0s - 80ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6199
# Epoch 341/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6199
# Epoch 342/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6200
# Epoch 343/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6200
# Epoch 344/2000
# 4/4 - 0s - 80ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6201
# Epoch 345/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6201
# Epoch 346/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6201
# Epoch 347/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6201
# Epoch 348/2000
# 4/4 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6202
# Epoch 349/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6202
# Epoch 350/2000
# 4/4 - 0s - 40ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6203
# Epoch 351/2000
# 4/4 - 0s - 41ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6203
# Epoch 352/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6203
# Epoch 353/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6203
# Epoch 354/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6204
# Epoch 355/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6204
# Epoch 356/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6204
# Epoch 357/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6204
# Epoch 358/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6204
# Epoch 359/2000
# 4/4 - 0s - 50ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6204
# Epoch 360/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6205
# Epoch 361/2000
# 4/4 - 0s - 80ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6205
# Epoch 362/2000
# 4/4 - 0s - 49ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6206
# Epoch 363/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6206
# Epoch 364/2000
# 4/4 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6207
# Epoch 365/2000
# 4/4 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6207
# Epoch 366/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6207
# Epoch 367/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6207
# Epoch 368/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6208
# Epoch 369/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6208
# Epoch 370/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6208
# Epoch 371/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6208
# Epoch 372/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6209
# Epoch 373/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6209
# Epoch 374/2000
# 4/4 - 0s - 39ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6210
# Epoch 375/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6210
# Epoch 376/2000
# 4/4 - 0s - 81ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6210
# Epoch 377/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6210
# Epoch 378/2000
# 4/4 - 0s - 56ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6211
# Epoch 379/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6211
# Epoch 380/2000
# 4/4 - 0s - 69ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6211
# Epoch 381/2000
# 4/4 - 0s - 80ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6211
# Epoch 382/2000
# 4/4 - 1s - 129ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6211
# Epoch 383/2000
# 4/4 - 0s - 69ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6212
# Epoch 384/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6212
# Epoch 385/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6212
# Epoch 386/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6212
# Epoch 387/2000
# 4/4 - 0s - 53ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6212
# Epoch 388/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6213
# Epoch 389/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6213
# Epoch 390/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6213
# Epoch 391/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6213
# Epoch 392/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6213
# Epoch 393/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6214
# Epoch 394/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6214
# Epoch 395/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6214
# Epoch 396/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6214
# Epoch 397/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6215
# Epoch 398/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6215
# Epoch 399/2000
# 4/4 - 0s - 80ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6215
# Epoch 400/2000
# 4/4 - 0s - 69ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6215
# Epoch 401/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6216
# Epoch 402/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6216
# Epoch 403/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6216
# Epoch 404/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6216
# Epoch 405/2000
# 4/4 - 0s - 70ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6217
# Epoch 406/2000
# 4/4 - 0s - 79ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6217
# Epoch 407/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6217
# Epoch 408/2000
# 4/4 - 0s - 41ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6217
# Epoch 409/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6218
# Epoch 410/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6218
# Epoch 411/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6218
# Epoch 412/2000
# 4/4 - 0s - 70ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6218
# Epoch 413/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6219
# Epoch 414/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6219
# Epoch 415/2000
# ...
# Epoch 1865/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6271
# Epoch 1866/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6271
# Epoch 1867/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1868/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1869/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1870/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1871/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1872/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1873/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1874/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1875/2000
# 4/4 - 0s - 50ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1876/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1877/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1878/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1879/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1880/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1881/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1882/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1883/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1884/2000
# 4/4 - 0s - 91ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6273
# Epoch 1885/2000
# 4/4 - 0s - 85ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1886/2000
# 4/4 - 0s - 87ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6272
# Epoch 1887/2000
# 4/4 - 0s - 69ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6273
# Epoch 1888/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6273
# Epoch 1889/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6273
# Epoch 1890/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6273
# Epoch 1891/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6273
# Epoch 1892/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6273
# Epoch 1893/2000
# 4/4 - 0s - 82ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6273
# Epoch 1894/2000
# 4/4 - 0s - 68ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1895/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1896/2000
# 4/4 - 0s - 49ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1897/2000
# 4/4 - 0s - 49ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1898/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1899/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1900/2000
# 4/4 - 0s - 41ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1901/2000
# 4/4 - 0s - 83ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1902/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1903/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1904/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1905/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1906/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1907/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1908/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1909/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1910/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1911/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1912/2000
# 4/4 - 0s - 84ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6274
# Epoch 1913/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6275
# Epoch 1914/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6275
# Epoch 1915/2000
# 4/4 - 0s - 40ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6275
# Epoch 1916/2000
# 4/4 - 0s - 44ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6275
# Epoch 1917/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6275
# Epoch 1918/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6275
# Epoch 1919/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6275
# Epoch 1920/2000
# 4/4 - 0s - 70ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6275
# Epoch 1921/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6275
# Epoch 1922/2000
# 4/4 - 0s - 56ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6275
# Epoch 1923/2000
# 4/4 - 0s - 52ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6275
# Epoch 1924/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6275
# Epoch 1925/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6275
# Epoch 1926/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6275
# Epoch 1927/2000
# 4/4 - 0s - 90ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6276
# Epoch 1928/2000
# 4/4 - 0s - 84ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6276
# Epoch 1929/2000
# 4/4 - 1s - 156ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6276
# Epoch 1930/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6276
# Epoch 1931/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6276
# Epoch 1932/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6276
# Epoch 1933/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6276
# Epoch 1934/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6276
# Epoch 1935/2000
# 4/4 - 0s - 49ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6276
# Epoch 1936/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6276
# Epoch 1937/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6277
# Epoch 1938/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6276
# Epoch 1939/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6277
# Epoch 1940/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6277
# Epoch 1941/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6277
# Epoch 1942/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6277
# Epoch 1943/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6277
# Epoch 1944/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6277
# Epoch 1945/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6277
# Epoch 1946/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6277
# Epoch 1947/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6277
# Epoch 1948/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6278
# Epoch 1949/2000
# 4/4 - 0s - 74ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6278
# Epoch 1950/2000
# 4/4 - 0s - 51ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6278
# Epoch 1951/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6278
# Epoch 1952/2000
# 4/4 - 0s - 79ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6278
# Epoch 1953/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6278
# Epoch 1954/2000
# 4/4 - 0s - 46ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6278
# Epoch 1955/2000
# 4/4 - 0s - 70ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6278
# Epoch 1956/2000
# 4/4 - 0s - 80ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6278
# Epoch 1957/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6278
# Epoch 1958/2000
# 4/4 - 0s - 49ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6278
# Epoch 1959/2000
# 4/4 - 0s - 70ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6279
# Epoch 1960/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6279
# Epoch 1961/2000
# 4/4 - 0s - 50ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6278
# Epoch 1962/2000
# 4/4 - 0s - 70ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6279
# Epoch 1963/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6279
# Epoch 1964/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6279
# Epoch 1965/2000
# 4/4 - 0s - 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6279
# Epoch 1966/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6279
# Epoch 1967/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6279
# Epoch 1968/2000
# 4/4 - 0s - 95ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6279
# Epoch 1969/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6279
# Epoch 1970/2000
# 4/4 - 0s - 64ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6279
# Epoch 1971/2000
# 4/4 - 0s - 67ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6279
# Epoch 1972/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6279
# Epoch 1973/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6279
# Epoch 1974/2000
# 4/4 - 0s - 72ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6279
# Epoch 1975/2000
# 4/4 - 0s - 40ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6279
# Epoch 1976/2000
# 4/4 - 0s - 80ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6280
# Epoch 1977/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6280
# Epoch 1978/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6280
# Epoch 1979/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6280
# Epoch 1980/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6280
# Epoch 1981/2000
# 4/4 - 0s - 48ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6280
# Epoch 1982/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6280
# Epoch 1983/2000
# 4/4 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6280
# Epoch 1984/2000
# 4/4 - 0s - 43ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6280
# Epoch 1985/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6280
# Epoch 1986/2000
# 4/4 - 0s - 75ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6280
# Epoch 1987/2000
# 4/4 - 0s - 73ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6280
# Epoch 1988/2000
# 4/4 - 0s - 40ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6281
# Epoch 1989/2000
# 4/4 - 0s - 47ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6281
# Epoch 1990/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6281
# Epoch 1991/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6281
# Epoch 1992/2000
# 4/4 - 0s - 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6281
# Epoch 1993/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6281
# Epoch 1994/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6281
# Epoch 1995/2000
# 4/4 - 0s - 49ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6281
# Epoch 1996/2000
# 4/4 - 0s - 71ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6281
# Epoch 1997/2000
# 4/4 - 0s - 40ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6281
# Epoch 1998/2000
# 4/4 - 0s - 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6281
# Epoch 1999/2000
# 4/4 - 0s - 42ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6282
# Epoch 2000/2000
# 4/4 - 0s - 45ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.6282
# CPU times: user 8min 15s, sys: 1min 8s, total: 9min 24s
# Wall time: 8min 32s

# %%
# Plot error
import matplotlib.pyplot as plt

plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Display the model summary
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)   │ (None, 8)              │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_1 (Embedding)   │ (None, 8, 16)          │          1,376 │ text_input[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_1 (Flatten)       │ (None, 128)            │              0 │ embedding_1[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 2048)           │        264,192 │ flatten_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 1024)           │      2,098,176 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ func_rating_input         │ (None, 1)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 512)            │        524,800 │ dense_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 32)             │             64 │ func_rating_input[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 544)            │              0 │ dense_6[0][0],         │
# │ (Concatenate)             │                        │                │ dense_7[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output (Dense)            │ (None, 6)              │          3,270 │ concatenate_1[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 8,675,636 (33.09 MB)
#  Trainable params: 2,891,878 (11.03 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 5,783,758 (22.06 MB)

# %%
! pip install --upgrade huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (0.29.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (2025.1.31)

# %%
from huggingface_hub import HfApi, login

hf_username = "Drona23"  # Replace with your Hugging Face username
repo_name = "my-tf-nn-model-v6"  # Change this as needed
repo_id = f"{hf_username}/{repo_name}"

# Authenticate with Hugging Face using your token
# Get your token from https://huggingface.co/settings/tokens
token = "YOUR_HUGGING_FACE_TOKEN" # Replace with your actual token
login(token)

api = HfApi()

# Create the repository
api.create_repo(repo_id=repo_id, exist_ok=True)

print(f"Repository created: https://huggingface.co/{repo_id}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/whoami-v2
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/hf_api.py in whoami(self, token)
#    1663         try:
# -> 1664             hf_raise_for_status(r)
#    1665         except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     480         # as well (request id and/or server error message)
# --> 481         raise _format(HfHubHTTPError, str(e), response) from e
#     482
#
# HfHubHTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/whoami-v2 (Request ID: Root=1-67c859e4-6ed20d64744879d007353af7;7f33fd83-16fc-4c39-aac9-bf8efcb8340d)
#
# Invalid credentials in Authorization header
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-36-29db33893b87> in <cell line: 0>()
#       8 # Get your token from https://huggingface.co/settings/tokens
#       9 token = "YOUR_HUGGING_FACE_TOKEN" # Replace with your actual token
# ---> 10 login(token)
#      11
#      12 api = HfApi()
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py in inner_f(*args, **kwargs)
#      99                     message += "\n\n" + custom_message
#     100                 warnings.warn(message, FutureWarning)
# --> 101             return f(*args, **kwargs)
#     102
#     103         return inner_f
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py in inner_f(*args, **kwargs)
#      29             extra_args = len(args) - len(all_args)
#      30             if extra_args <= 0:
# ---> 31                 return f(*args, **kwargs)
#      32             # extra_args > 0
#      33             args_msg = [
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/_login.py in login(token, add_to_git_credential, new_session, write_permission)
#     124                 "you want to set the git credential as well."
#     125             )
# --> 126         _login(token, add_to_git_credential=add_to_git_credential)
#     127     elif is_notebook():
#     128         notebook_login(new_session=new_session)
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/_login.py in _login(token, add_to_git_credential)
#     402         raise ValueError("You must use your personal account token, not an organization token.")
#     403
# --> 404     token_info = whoami(token)
#     405     permission = token_info["auth"]["accessToken"]["role"]
#     406     logger.info(f"Token is valid (permission: {permission}).")
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/hf_api.py in whoami(self, token)
#    1675             elif effective_token == _get_token_from_file():
#    1676                 error_message += " The token stored is invalid. Please run `huggingface-cli login` to update it."
# -> 1677             raise HTTPError(error_message, request=e.request, response=e.response) from e
#    1678         return r.json()
#    1679
#
# HTTPError: Invalid user token.

# %%
from huggingface_hub import HfApi, login

hf_username = "DronA23"  # Replace with your Hugging Face username
repo_name = "my-tf-nn-model-v6"  # Change this as needed
repo_id = f"{hf_username}/{repo_name}"

# Authenticate with Hugging Face using your token
# Get your token from https://huggingface.co/settings/tokens
token = "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"  # Replace with your actual token
login(token)

api = HfApi()

# Create the repository
api.create_repo(repo_id=repo_id, exist_ok=True)

print(f"Repository created: https://huggingface.co/{repo_id}")
# Out:
# Repository created: https://huggingface.co/DronA23/my-tf-nn-model-v6

# %%
import pickle
import os
from huggingface_hub import HfApi
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# Define save directory
model_dir = "./saved_model"
os.makedirs(model_dir, exist_ok=True)

# Save the model
model_path = os.path.join(model_dir, "model.keras")
model.save(model_path)

# Save the tokenizer as a pickle file
tokenizer_path = os.path.join(model_dir, "tokenizer.pkl")
with open(tokenizer_path, "wb") as f:
    pickle.dump(tokenizer, f)

# Upload model and tokenizer to Hugging Face
# **Change 'eagle0504' to your Hugging Face username**
repo_id = f"{hf_username}/{repo_name}"  # Change as needed
api = HfApi()

api.upload_file(path_or_fileobj=model_path, path_in_repo="model.keras", repo_id=repo_id)
api.upload_file(path_or_fileobj=tokenizer_path, path_in_repo="tokenizer.pkl", repo_id=repo_id)

print(f"Model and tokenizer successfully pushed to: https://huggingface.co/{repo_id}")
# Out:
# model.keras:   0%|          | 0.00/34.8M [00:00<?, ?B/s]
# tokenizer.pkl:   0%|          | 0.00/2.65k [00:00<?, ?B/s]
# Model and tokenizer successfully pushed to: https://huggingface.co/DronA23/my-tf-nn-model-v6

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from huggingface_hub import hf_hub_download

# Set Keras backend to JAX (Optional, only needed if you want to experiment with JAX backend)
os.environ["KERAS_BACKEND"] = "jax"

# Define repo ID and model filename
# repo_id = "eagle0504/my-tf-nn-model" # we already defined it above
filename = "model.keras"  # Ensure this matches what was uploaded

# Download the model
model_path = hf_hub_download(repo_id=repo_id, filename=filename)

# Load the Keras model
new_model = keras.models.load_model(model_path)

print("Model loaded successfully!")
# Out:
# model.keras:   0%|          | 0.00/34.8M [00:00<?, ?B/s]
# Model loaded successfully!

# %%
new_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)   │ (None, 8)              │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_1 (Embedding)   │ (None, 8, 16)          │          1,376 │ text_input[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_1 (Flatten)       │ (None, 128)            │              0 │ embedding_1[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 2048)           │        264,192 │ flatten_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 1024)           │      2,098,176 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ func_rating_input         │ (None, 1)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 512)            │        524,800 │ dense_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 32)             │             64 │ func_rating_input[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 544)            │              0 │ dense_6[0][0],         │
# │ (Concatenate)             │                        │                │ dense_7[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output (Dense)            │ (None, 6)              │          3,270 │ concatenate_1[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 8,675,636 (33.09 MB)
#  Trainable params: 2,891,878 (11.03 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 5,783,758 (22.06 MB)

# %%
import pickle
from huggingface_hub import hf_hub_download
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Define repo details
# repo_id = "eagle0504/my-tf-nn-model" # we already defined above

# Download model
# model_path = hf_hub_download(repo_id=repo_id, filename="model.keras")
# new_model = keras.models.load_model(model_path)

# Download tokenizer
tokenizer_path = hf_hub_download(repo_id=repo_id, filename="tokenizer.pkl")

# Load the tokenizer
with open(tokenizer_path, "rb") as f:
    tokenizer = pickle.load(f)

print("Model and tokenizer loaded successfully!")

# Sample test data
test_texts = [
    "How to improve focus and concentration?",
    "What are the side effects of lack of sleep?",
]

# Preprocess test data using the loaded tokenizer
max_length = model.input_shape[0][1]  # Get max_length from model input shape
X_text_test = tokenizer.texts_to_sequences(test_texts)
X_text_test = pad_sequences(X_text_test, maxlen=max_length, padding='post')

# Dummy numeric input (func_rating)
X_func_test = np.array([5, 4]).reshape(-1, 1)
# Make predictions
predictions = new_model.predict({"text_input": X_text_test, "func_rating_input": X_func_test})

# Display results
for i, text in enumerate(test_texts):
    print(f"Prompt: {text}")
    print(f"Predicted Rating: {predictions[i][0]:.2f}")
    print("-" * 50)
# Out:
# tokenizer.pkl:   0%|          | 0.00/2.65k [00:00<?, ?B/s]
# Model and tokenizer loaded successfully!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Prompt: How to improve focus and concentration?
# Predicted Rating: 0.00
# --------------------------------------------------
# Prompt: What are the side effects of lack of sleep?
# Predicted Rating: 0.00
# --------------------------------------------------
